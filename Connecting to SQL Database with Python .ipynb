# %%
# !pip install mysql-connector-python

# %%
# !pip install sqlalchemy
# !pip install pyMySQL

# %%
import pandas as pd
import sqlalchemy

# %%
import mysql.connector as connection

# %%
mydb = connection.connect(host="localhost",database='sakila',user="root", passwd="Victor99@@",use_pure=True)

# %%
query1='show databases'
cur = mydb.cursor()
cur.execute(query1)
res = cur.fetchall()
res
# Out:
# [('exam',),
#  ('house',),
#  ('information_schema',),
#  ('movies',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('structured_relation_database',),
#  ('sys',),
#  ('world',)]

# %%
query2='use sakila'
cur = mydb.cursor()
cur.execute(query2)
res = cur.fetchall()
res
# Out:
# []

# %%
query3='show tables'
cur = mydb.cursor()
cur.execute(query3)
res = cur.fetchall()
res
# Out:
# [('actor',),
#  ('actor_info',),
#  ('address',),
#  ('category',),
#  ('city',),
#  ('country',),
#  ('customer',),
#  ('customer_list',),
#  ('film',),
#  ('film_actor',),
#  ('film_category',),
#  ('film_list',),
#  ('film_text',),
#  ('inventory',),
#  ('language',),
#  ('nicer_but_slower_film_list',),
#  ('payment',),
#  ('rental',),
#  ('sales_by_film_category',),
#  ('sales_by_store',),
#  ('staff',),
#  ('staff_list',),
#  ('store',)]

# %%
query='select * from actor'

# %%
df = pd.read_sql(query,mydb)

# %%
df
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3       edet         CHASE 2022-06-09 03:35:23
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
df.head()
# Out:
#    actor_id first_name     last_name         last_update
# 0         1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1         2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2         3       edet         CHASE 2022-06-09 03:35:23
# 3         4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4         5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33

# %%
df['current date']=2022

# %%
df
# Out:
#      actor_id first_name     last_name         last_update  current date
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33          2022
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33          2022
# 2           3       edet         CHASE 2022-06-09 03:35:23          2022
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33          2022
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33          2022
# ..        ...        ...           ...                 ...           ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33          2022
# 196       197      REESE          WEST 2006-02-15 04:34:33          2022
# 197       198       MARY        KEITEL 2006-02-15 04:34:33          2022
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33          2022
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33          2022
#
# [200 rows x 5 columns]

# %%
df['last_update_day']=pd.to_datetime(df.last_update,format='%d/%m/%y').dt.day

# %%
df
# Out:
#      actor_id first_name     last_name         last_update  current date  \
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33          2022
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33          2022
# 2           3       edet         CHASE 2022-06-09 03:35:23          2022
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33          2022
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33          2022
# ..        ...        ...           ...                 ...           ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33          2022
# 196       197      REESE          WEST 2006-02-15 04:34:33          2022
# 197       198       MARY        KEITEL 2006-02-15 04:34:33          2022
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33          2022
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33          2022
#
#      last_update_day
# 0                 15
# 1                 15
# 2                  9
# ...

# %%
df['last_update_year']=pd.to_datetime(df.last_update,format='%d/%m/%y').dt.year

# %%
df
# Out:
#      actor_id first_name     last_name         last_update  current date  \
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33          2022
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33          2022
# 2           3       edet         CHASE 2022-06-09 03:35:23          2022
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33          2022
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33          2022
# ..        ...        ...           ...                 ...           ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33          2022
# 196       197      REESE          WEST 2006-02-15 04:34:33          2022
# 197       198       MARY        KEITEL 2006-02-15 04:34:33          2022
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33          2022
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33          2022
#
#      last_update_day  last_update_year
# 0                 15              2006
# ...

# %%
df.to_csv('sakila_update.csv', index=False)
